# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/glassdoor-job-reviews/glassdoor_reviews.csv

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv('/kaggle/input/glassdoor-job-reviews/glassdoor_reviews.csv', index_col=[0], parse_dates=['date_review']) 
df.head()
# Out:
#                       date_review              job_title  \
# firm
# AFH-Wealth-Management  2015-04-05
# AFH-Wealth-Management  2015-12-11   Office Administrator
# AFH-Wealth-Management  2016-01-28   Office Administrator
# AFH-Wealth-Management  2016-04-16
# AFH-Wealth-Management  2016-04-23   Office Administrator
#
#                                                   current  \
# firm
# AFH-Wealth-Management                    Current Employee
# AFH-Wealth-Management  Current Employee, more than 1 year
# AFH-Wealth-Management  Current Employee, less than 1 year
# AFH-Wealth-Management                    Current Employee
# AFH-Wealth-Management  Current Employee, more than 1 year
#
#                                            location  overall_rating  \
# firm
# AFH-Wealth-Management                           NaN               2
# AFH-Wealth-Management  Bromsgrove, England, England               2
# AFH-Wealth-Management  Bromsgrove, England, England               1
# AFH-Wealth-Management                           NaN               5
# AFH-Wealth-Management  Bromsgrove, England, England               1
#
#                        work_life_balance  culture_values  diversity_inclusion  \
# firm
# AFH-Wealth-Management                4.0             3.0                  NaN
# AFH-Wealth-Management                3.0             1.0                  NaN
# AFH-Wealth-Management                1.0             1.0                  NaN
# AFH-Wealth-Management                2.0             3.0                  NaN
# AFH-Wealth-Management                2.0             1.0                  NaN
#
#                        career_opp  comp_benefits  senior_mgmt recommend  \
# firm
# AFH-Wealth-Management         2.0            3.0          3.0         x
# AFH-Wealth-Management         2.0            1.0          4.0         x
# AFH-Wealth-Management         1.0            1.0          1.0         x
# AFH-Wealth-Management         2.0            2.0          3.0         x
# AFH-Wealth-Management         2.0            1.0          1.0         x
#
#                       ceo_approv outlook  \
# firm
# AFH-Wealth-Management          o       r
# AFH-Wealth-Management          o       r
# AFH-Wealth-Management          o       x
# AFH-Wealth-Management          o       r
# AFH-Wealth-Management          o       x
#
#                                                       headline  \
# firm
# AFH-Wealth-Management  Young colleagues, poor micro management
# AFH-Wealth-Management             Excellent staff, poor salary
# AFH-Wealth-Management          Low salary, bad micromanagement
# AFH-Wealth-Management            Over promised under delivered
# AFH-Wealth-Management                   client reporting admin
#
#                                                                     pros  \
# firm
# AFH-Wealth-Management  Very friendly and welcoming to new staff. Easy...
# AFH-Wealth-Management      Friendly, helpful and hard-working colleagues
# AFH-Wealth-Management  Easy to get the job even without experience in...
# AFH-Wealth-Management                            Nice staff to work with
# AFH-Wealth-Management              Easy to get the job, Nice colleagues.
#
#                                                                     cons
# firm
# AFH-Wealth-Management    Poor salaries, poor training and communication.
# AFH-Wealth-Management  Poor salary which doesn't improve much with pr...
# AFH-Wealth-Management  Very low salary, poor working conditions, very...
# AFH-Wealth-Management           No career progression and salary is poor
# AFH-Wealth-Management  Abysmal pay, around minimum wage. No actual tr...

# %%
df.shape
# Out:
# (838566, 17)

# %%
df.columns
# Out:
# Index(['date_review', 'job_title', 'current', 'location', 'overall_rating',
#        'work_life_balance', 'culture_values', 'diversity_inclusion',
#        'career_opp', 'comp_benefits', 'senior_mgmt', 'recommend', 'ceo_approv',
#        'outlook', 'headline', 'pros', 'cons'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838566 entries, AFH-Wealth-Management to the-LEGO-Group
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date_review          838566 non-null  datetime64[ns]
#  1   job_title            838566 non-null  object
#  2   current              838566 non-null  object
#  3   location             541228 non-null  object
#  4   overall_rating       838566 non-null  int64
#  5   work_life_balance    688672 non-null  float64
#  6   culture_values       647193 non-null  float64
#  7   diversity_inclusion  136066 non-null  float64
#  8   career_opp           691065 non-null  float64
#  9   comp_benefits        688484 non-null  float64
#  10  senior_mgmt          682690 non-null  float64
#  11  recommend            838566 non-null  object
#  12  ceo_approv           838566 non-null  object
#  13  outlook              838566 non-null  object
#  14  headline             836347 non-null  object
#  15  pros                 838566 non-null  object
#  16  cons                 838558 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(9)
# memory usage: 115.2+ MB

# %%
df.drop_duplicates(inplace = True)
len(df)
# Out:
# 805051

# %%
df.isnull().sum()
# Out:
# date_review                 0
# job_title                   0
# current                     0
# location               285090
# overall_rating              0
# work_life_balance      144060
# culture_values         183364
# diversity_inclusion    674160
# career_opp             141726
# comp_benefits          144242
# senior_mgmt            149804
# recommend                   0
# ceo_approv                  0
# outlook                     0
# headline                 2099
# pros                        0
# cons                        8
# dtype: int64

# %%
rating_columns = df.select_dtypes(include = ['float64','int64'])
string_columns = df.select_dtypes(exclude = ['float64','int64'])
df_column_sorted = pd.concat([string_columns, rating_columns], axis = 1)

df_column_sorted.head()
# Out:
#                       date_review              job_title  \
# firm
# AFH-Wealth-Management  2015-04-05
# AFH-Wealth-Management  2015-12-11   Office Administrator
# AFH-Wealth-Management  2016-01-28   Office Administrator
# AFH-Wealth-Management  2016-04-16
# AFH-Wealth-Management  2016-04-23   Office Administrator
#
#                                                   current  \
# firm
# AFH-Wealth-Management                    Current Employee
# AFH-Wealth-Management  Current Employee, more than 1 year
# AFH-Wealth-Management  Current Employee, less than 1 year
# AFH-Wealth-Management                    Current Employee
# AFH-Wealth-Management  Current Employee, more than 1 year
#
#                                            location recommend ceo_approv  \
# firm
# AFH-Wealth-Management                           NaN         x          o
# AFH-Wealth-Management  Bromsgrove, England, England         x          o
# AFH-Wealth-Management  Bromsgrove, England, England         x          o
# AFH-Wealth-Management                           NaN         x          o
# AFH-Wealth-Management  Bromsgrove, England, England         x          o
#
#                       outlook                                 headline  \
# firm
# AFH-Wealth-Management       r  Young colleagues, poor micro management
# AFH-Wealth-Management       r             Excellent staff, poor salary
# AFH-Wealth-Management       x          Low salary, bad micromanagement
# AFH-Wealth-Management       r            Over promised under delivered
# AFH-Wealth-Management       x                   client reporting admin
#
#                                                                     pros  \
# firm
# AFH-Wealth-Management  Very friendly and welcoming to new staff. Easy...
# AFH-Wealth-Management      Friendly, helpful and hard-working colleagues
# AFH-Wealth-Management  Easy to get the job even without experience in...
# AFH-Wealth-Management                            Nice staff to work with
# AFH-Wealth-Management              Easy to get the job, Nice colleagues.
#
#                                                                     cons  \
# firm
# AFH-Wealth-Management    Poor salaries, poor training and communication.
# AFH-Wealth-Management  Poor salary which doesn't improve much with pr...
# AFH-Wealth-Management  Very low salary, poor working conditions, very...
# AFH-Wealth-Management           No career progression and salary is poor
# AFH-Wealth-Management  Abysmal pay, around minimum wage. No actual tr...
#
#                        overall_rating  work_life_balance  culture_values  \
# firm
# AFH-Wealth-Management               2                4.0             3.0
# AFH-Wealth-Management               2                3.0             1.0
# AFH-Wealth-Management               1                1.0             1.0
# AFH-Wealth-Management               5                2.0             3.0
# AFH-Wealth-Management               1                2.0             1.0
#
#                        diversity_inclusion  career_opp  comp_benefits  \
# firm
# AFH-Wealth-Management                  NaN         2.0            3.0
# AFH-Wealth-Management                  NaN         2.0            1.0
# AFH-Wealth-Management                  NaN         1.0            1.0
# AFH-Wealth-Management                  NaN         2.0            2.0
# AFH-Wealth-Management                  NaN         2.0            1.0
#
#                        senior_mgmt
# firm
# AFH-Wealth-Management          3.0
# AFH-Wealth-Management          4.0
# AFH-Wealth-Management          1.0
# AFH-Wealth-Management          3.0
# AFH-Wealth-Management          1.0

# %%
f1 = df['recommend'].value_counts()
f2 = df['ceo_approv'].value_counts()
f3 = df['outlook'].value_counts()

print(f1)
print(f2)
print(f3)
# Out:
# v    411103
# o    224357
# x    169591
# Name: recommend, dtype: int64
# o    298443
# v    275936
# r    170180
# x     60492
# Name: ceo_approv, dtype: int64
# v    290109
# o    281821
# r    148915
# x     84206
# Name: outlook, dtype: int64

# %% [markdown]
# v - Positive, r - Mild, x - Negative, o - No opinion

# %%
for i in range(1,10):
    print('Author Years:', df['current'][i])
    print('Author Title:', df['job_title'][i])
    print('Author Summary:', df['headline'][i])
    print('Author Pro:', df['pros'][i])
    print('Author Con:', df['pros'][i])
    print('====================')
# Out:
# Author Years: Current Employee, more than 1 year
# Author Title:  Office Administrator
# Author Summary: Excellent staff, poor salary
# Author Pro: Friendly, helpful and hard-working colleagues
# Author Con: Friendly, helpful and hard-working colleagues
# ====================
# Author Years: Current Employee, less than 1 year
# Author Title:  Office Administrator
# Author Summary: Low salary, bad micromanagement
# Author Pro: Easy to get the job even without experience in finance
# Author Con: Easy to get the job even without experience in finance
# ====================
# Author Years: Current Employee
# Author Title:
# Author Summary: Over promised under delivered
# Author Pro: Nice staff to work with
# Author Con: Nice staff to work with
# ====================
# Author Years: Current Employee, more than 1 year
# Author Title:  Office Administrator
# Author Summary: client reporting admin
# Author Pro: Easy to get the job, Nice colleagues.
# Author Con: Easy to get the job, Nice colleagues.
# ====================
# Author Years: Current Employee, less than 1 year
# Author Title:  Office Administrator
# Author Summary: Office administrator
# Author Pro: Some good people to work with.
#
# Flexible working.
#
# Out of hours language classes and aerobics.
#
# Financial support for exams.
# Author Con: Some good people to work with.
#
# Flexible working.
#
# Out of hours language classes and aerobics.
#
# Financial support for exams.
# ====================
# Author Years: Former Employee
# Author Title:  IFA
# Author Summary: It horrible management
# Author Pro: Good investment management strategy. Overall there are individual admin staff that are very nice and helpful
# Author Con: Good investment management strategy. Overall there are individual admin staff that are very nice and helpful
# ====================
# Author Years: Current Employee, more than 5 years
# Author Title:  Anonymous Employee
# Author Summary: Good place to work
# Author Pro: The people are great and the culture is very forward thinking. Lots of development opportunities and really invest in educating their employees.
# Author Con: The people are great and the culture is very forward thinking. Lots of development opportunities and really invest in educating their employees.
# ====================
# Author Years: Former Employee, more than 1 year
# Author Title:  Anonymous Employee
# Author Summary: I liked working for AFH
# Author Pro: Nice Staff, good HR Team.
# Feels vibrant and forward thinking.
# Flexible hours (worked for me).
# Good place to start your career.
# Author Con: Nice Staff, good HR Team.
# Feels vibrant and forward thinking.
# Flexible hours (worked for me).
# Good place to start your career.
# ====================
# Author Years: Former Employee, more than 3 years
# Author Title:  Technician
# Author Summary: Honest Review
# Author Pro: Made some life time friends.
# Author Con: Made some life time friends.
# ====================

# %%
type(pd.isna(df['current']))
# Out:
# pandas.core.series.Series

# %%
def extract_cat_data(row):
    
    # 1. extract current/former employee flags from'Author Years'
    if not pd.isna(row['current']):
        if "Current Employee" in row['current']:
            row['Current Employee'] = 1
        elif "Former Employee" in row['current']:
            row['Current Employee'] = 0
        elif "Former Intern" in row['current']:
            row['Current Employee'] = 0
        elif "Current Contractor" in row['current']:
            row['Current Employee'] = 0
        elif "KEY NOT FOUND" in row['current']:
            row['Current Employee'] = 0
        else:
            row['Current Employee'] = np.NaN  
    
    str_to_num = row['current'].replace("a year" , "1 year")
    regrex = r'\d+'
    tenure = re.findall(regrex , str_to_num)
    
    if tenure:
        row['tenure'] = int(tenure[0])
        if "more than" in row['current']:
            row['tenure'] += 0.5
        elif "less than" in row['current']:
            row['tenure'] -=0.5
    else:
        row['tenure'] = np.NaN
            
    
    if not pd.isna(row['recommend']):
        if row['recommend'] == "v":
            row['recommend'] = 1
        elif row['recommend'] == "x":
            row['recommend'] = -1
        elif row['recommend'] == "o" or row['recommend'] == "r":
            row['recommend'] = 0
       
    
    if not pd.isna(row['ceo_approv']):
        if row['ceo_approv'] == "v":
            row['ceo_approv'] = 1
        elif row['ceo_approv'] == "x":
            row['ceo_approv'] = -1
        elif row['ceo_approv'] == "o" or row['ceo_approv'] == "r":
            row['ceo_approv'] = 0
            
    
    if not pd.isna(row['outlook']):
        if row['outlook'] == "v":
            row['outlook'] = 1
        elif row['outlook'] == "x":
            row['outlook'] = -1
        elif row['outlook'] == "o" or row['outlook'] == "r":
            row['outlook'] = 0
            
    

    return row

df_cat_extracted = df.apply(extract_cat_data, axis=1)
df_cat_extracted
# Out:
#                       date_review                         job_title  \
# firm
# AFH-Wealth-Management  2015-04-05
# AFH-Wealth-Management  2015-12-11              Office Administrator
# AFH-Wealth-Management  2016-01-28              Office Administrator
# AFH-Wealth-Management  2016-04-16
# AFH-Wealth-Management  2016-04-23              Office Administrator
# ...                           ...                               ...
# the-LEGO-Group         2021-06-02                 Marketing Manager
# the-LEGO-Group         2021-06-03                   Sales Associate
# the-LEGO-Group         2021-06-03                        Strategist
# the-LEGO-Group         2021-06-04   Customer Service Representative
# the-LEGO-Group         2021-06-04        Human Resources Specialist
#
#                                                    current  \
# firm
# AFH-Wealth-Management                     Current Employee
# AFH-Wealth-Management   Current Employee, more than 1 year
# AFH-Wealth-Management   Current Employee, less than 1 year
# AFH-Wealth-Management                     Current Employee
# AFH-Wealth-Management   Current Employee, more than 1 year
# ...                                                    ...
# the-LEGO-Group         Current Employee, more than 5 years
# the-LEGO-Group          Current Employee, less than 1 year
# the-LEGO-Group                            Current Employee
# the-LEGO-Group          Current Employee, less than 1 year
# the-LEGO-Group         Current Employee, more than 3 years
#
#                                                          location  \
# firm
# AFH-Wealth-Management                                         NaN
# AFH-Wealth-Management                Bromsgrove, England, England
# AFH-Wealth-Management                Bromsgrove, England, England
# AFH-Wealth-Management                                         NaN
# AFH-Wealth-Management                Bromsgrove, England, England
# ...                                                           ...
# the-LEGO-Group                          München, Bavaria, Bavaria
# the-LEGO-Group                           London, England, England
# the-LEGO-Group                                                NaN
# the-LEGO-Group                                                NaN
# the-LEGO-Group         Kladno, Central Bohemian, Central Bohemian
#
#                        overall_rating  work_life_balance  culture_values  \
# firm
# AFH-Wealth-Management               2                4.0             3.0
# AFH-Wealth-Management               2                3.0             1.0
# AFH-Wealth-Management               1                1.0             1.0
# AFH-Wealth-Management               5                2.0             3.0
# AFH-Wealth-Management               1                2.0             1.0
# ...                               ...                ...             ...
# the-LEGO-Group                      5                4.0             5.0
# the-LEGO-Group                      3                NaN             NaN
# the-LEGO-Group                      4                5.0             5.0
# the-LEGO-Group                      5                NaN             NaN
# the-LEGO-Group                      5                4.0             5.0
#
#                        diversity_inclusion  career_opp  comp_benefits  \
# firm
# AFH-Wealth-Management                  NaN         2.0            3.0
# AFH-Wealth-Management                  NaN         2.0            1.0
# AFH-Wealth-Management                  NaN         1.0            1.0
# AFH-Wealth-Management                  NaN         2.0            2.0
# AFH-Wealth-Management                  NaN         2.0            1.0
# ...                                    ...         ...            ...
# the-LEGO-Group                         4.0         4.0            4.0
# the-LEGO-Group                         NaN         NaN            NaN
# the-LEGO-Group                         5.0         3.0            5.0
# the-LEGO-Group                         NaN         NaN            NaN
# the-LEGO-Group                         4.0         4.0            5.0
#
#                        senior_mgmt  recommend  ceo_approv  outlook  \
# firm
# AFH-Wealth-Management          3.0         -1           0        0
# AFH-Wealth-Management          4.0         -1           0        0
# AFH-Wealth-Management          1.0         -1           0       -1
# AFH-Wealth-Management          3.0         -1           0        0
# AFH-Wealth-Management          1.0         -1           0       -1
# ...                            ...        ...         ...      ...
# the-LEGO-Group                 4.0          1           1        1
# the-LEGO-Group                 NaN          0           0        0
# the-LEGO-Group                 3.0          1           0        0
# the-LEGO-Group                 NaN          0           0        0
# the-LEGO-Group                 5.0          1           1        0
#
#                                                               headline  \
# firm
# AFH-Wealth-Management          Young colleagues, poor micro management
# AFH-Wealth-Management                     Excellent staff, poor salary
# AFH-Wealth-Management                  Low salary, bad micromanagement
# AFH-Wealth-Management                    Over promised under delivered
# AFH-Wealth-Management                           client reporting admin
# ...                                                                ...
# the-LEGO-Group                  Just an awesome company to work for!!!
# the-LEGO-Group                                         working at lego
# the-LEGO-Group                  not interested in growing their people
# the-LEGO-Group                                     Great Place to Work
# the-LEGO-Group         I strongly recommend the LEGO Group as employer
#
#                                                                     pros  \
# firm
# AFH-Wealth-Management  Very friendly and welcoming to new staff. Easy...
# AFH-Wealth-Management      Friendly, helpful and hard-working colleagues
# AFH-Wealth-Management  Easy to get the job even without experience in...
# AFH-Wealth-Management                            Nice staff to work with
# AFH-Wealth-Management              Easy to get the job, Nice colleagues.
# ...                                                                  ...
# the-LEGO-Group         Great company values, awesome product, smart c...
# the-LEGO-Group                             staff discount is really nice
# the-LEGO-Group                           loved brand for a lot of people
# the-LEGO-Group                 Good wages, good hours, lots of resources
# the-LEGO-Group         The LEGO Group is company with many opportunit...
#
#                                                                     cons  \
# firm
# AFH-Wealth-Management    Poor salaries, poor training and communication.
# AFH-Wealth-Management  Poor salary which doesn't improve much with pr...
# AFH-Wealth-Management  Very low salary, poor working conditions, very...
# AFH-Wealth-Management           No career progression and salary is poor
# AFH-Wealth-Management  Abysmal pay, around minimum wage. No actual tr...
# ...                                                                  ...
# the-LEGO-Group              Not very easy to transfer to other locations
# the-LEGO-Group         micro managing is a hassle\r\ncan become menta...
# the-LEGO-Group         you can spend 6-10 years without any promotion...
# the-LEGO-Group         Working every other weekend, busy seasons can ...
# the-LEGO-Group         Many things are centralized in Denmark and rel...
#
#                        Current Employee  tenure
# firm
# AFH-Wealth-Management               1.0     NaN
# AFH-Wealth-Management               1.0     1.5
# AFH-Wealth-Management               1.0     0.5
# AFH-Wealth-Management               1.0     NaN
# AFH-Wealth-Management               1.0     1.5
# ...                                 ...     ...
# the-LEGO-Group                      1.0     5.5
# the-LEGO-Group                      1.0     0.5
# the-LEGO-Group                      1.0     NaN
# the-LEGO-Group                      1.0     0.5
# the-LEGO-Group                      1.0     3.5
#
# [805051 rows x 19 columns]

# %%
df_cleaned = df_cat_extracted.drop(columns = ['current'])

# %% [markdown]
# **Reorder for a Better View**

# %%
df_cleaned = df_cleaned[['date_review', 'location', 'job_title', 'tenure', 'Current Employee', 
       'headline', 'pros', 'cons', 'recommend', 'ceo_approv','outlook', 'overall_rating',
       'work_life_balance', 'culture_values', 'diversity_inclusion',
       'career_opp', 'comp_benefits', 'senior_mgmt']]

# %%
df_cleaned.set_index('date_review' , inplace = True)

# %%
df_cleaned = df_cleaned.sort_index()
df_cleaned.head(10)
# Out:
#                       location                   job_title  tenure  \
# date_review
# 2008-01-31       Cupertino, CA      Senior Product Manager     NaN
# 2008-02-05   Mountain View, CA           Software Engineer     NaN
# 2008-02-11   Mountain View, CA           Software Engineer     NaN
# 2008-02-14       Cupertino, CA           Software Engineer     NaN
# 2008-02-14   Mountain View, CA           Software Engineer     NaN
# 2008-02-14   Mountain View, CA           Software Engineer     NaN
# 2008-02-15       Cupertino, CA             Product Manager     NaN
# 2008-02-25   Mountain View, CA             Project Manager     NaN
# 2008-02-27   San Francisco, CA   Technical Account Manager     NaN
# 2008-02-27   San Francisco, CA           Account Executive     NaN
#
#              Current Employee  \
# date_review
# 2008-01-31                1.0
# 2008-02-05                1.0
# 2008-02-11                1.0
# 2008-02-14                1.0
# 2008-02-14                1.0
# 2008-02-14                1.0
# 2008-02-15                1.0
# 2008-02-25                1.0
# 2008-02-27                1.0
# 2008-02-27                1.0
#
#                                                       headline  \
# date_review
# 2008-01-31   We make products that poeple enjoy buying and ...
# 2008-02-05   Freedom within the company and lots of things ...
# 2008-02-11   Work with smart people who are willing to shar...
# 2008-02-14   It is a different job because of all of the di...
# 2008-02-14   One of the best jobs of my life because I work...
# 2008-02-14   Working for Google has been exciting over the ...
# 2008-02-15   Working at Apple is the hardest job you will e...
# 2008-02-25      Dynamic place to work due to diverse cultures.
# 2008-02-27   Growing company that is supportive with a lot ...
# 2008-02-27   Very challenging, yet big rewards. You get a c...
#
#                                                           pros  \
# date_review
# 2008-01-31   The people we work with are great and I can't ...
# 2008-02-05   I work w/ a diverse set of people. You have ha...
# 2008-02-11   People are willing to share knowledge which is...
# 2008-02-14   The big positive for me is that I really do en...
# 2008-02-14   To repeat what I wrote before, the people I wo...
# 2008-02-14   The name recognition that goes along w/ the jo...
# 2008-02-15   When you work at a place like Apple you have a...
# 2008-02-25   The variety of different projects and the spee...
# 2008-02-27   A positive is that they do a really good job t...
# 2008-02-27   You have the ability to advance vertically or ...
#
#                                                           cons  recommend  \
# date_review
# 2008-01-31   You have to be careful because this job can ta...          1
# 2008-02-05   Google can be a bit overwhelming w/ the volume...          1
# 2008-02-11   A company like this requires a lot of long hou...          1
# 2008-02-14   I suppose that a con would be that there is a ...          1
# 2008-02-14   Sometimes being that it is such a big company ...          1
# 2008-02-14   It is very difficult to know where management ...          0
# 2008-02-15   The people at Apple are living on the bleeding...          1
# 2008-02-25   Sometimes people need to realize when we work ...          1
# 2008-02-27   I would say that I was rather impressed becaus...          1
# 2008-02-27   As with big companies like this, it can be bur...          1
#
#              ceo_approv  outlook  overall_rating  work_life_balance  \
# date_review
# 2008-01-31            1        0               5                3.0
# 2008-02-05            1        0               4                4.0
# 2008-02-11            1        0               5                4.0
# 2008-02-14            1        0               4                4.0
# 2008-02-14            1        0               5                5.0
# 2008-02-14            1        0               3                4.0
# 2008-02-15            1        0               5                4.0
# 2008-02-25            1        0               5                5.0
# 2008-02-27            1        0               5                5.0
# 2008-02-27            1        0               5                4.0
#
#              culture_values  diversity_inclusion  career_opp  comp_benefits  \
# date_review
# 2008-01-31              NaN                  NaN         3.0            4.0
# 2008-02-05              NaN                  NaN         4.0            4.0
# 2008-02-11              NaN                  NaN         5.0            5.0
# 2008-02-14              NaN                  NaN         3.0            4.0
# 2008-02-14              NaN                  NaN         4.0            4.0
# 2008-02-14              NaN                  NaN         3.0            4.0
# 2008-02-15              NaN                  NaN         5.0            5.0
# 2008-02-25              NaN                  NaN         5.0            5.0
# 2008-02-27              NaN                  NaN         5.0            5.0
# 2008-02-27              NaN                  NaN         5.0            4.0
#
#              senior_mgmt
# date_review
# 2008-01-31           4.0
# 2008-02-05           4.0
# 2008-02-11           5.0
# 2008-02-14           3.0
# 2008-02-14           5.0
# 2008-02-14           4.0
# 2008-02-15           5.0
# 2008-02-25           5.0
# 2008-02-27           5.0
# 2008-02-27           4.0

# %%
df_cleaned.isnull().sum()
# Out:
# location               285090
# job_title                   0
# tenure                 341342
# Current Employee           13
# headline                 2099
# pros                        0
# cons                        8
# recommend                   0
# ceo_approv                  0
# outlook                     0
# overall_rating              0
# work_life_balance      144060
# culture_values         183364
# diversity_inclusion    674160
# career_opp             141726
# comp_benefits          144242
# senior_mgmt            149804
# dtype: int64

# %% [markdown]
# **Data Analysis**

# %%
df_cleaned.describe()
# Out:
#               tenure  Current Employee      recommend     ceo_approv  \
# count  463709.000000     805038.000000  805051.000000  805051.000000
# mean        3.447672          0.585287       0.299996       0.267615
# std         3.003044          0.492673       0.794554       0.588455
# min         0.500000          0.000000      -1.000000      -1.000000
# 25%         1.500000          0.000000       0.000000       0.000000
# 50%         3.500000          1.000000       1.000000       0.000000
# 75%         5.500000          1.000000       1.000000       1.000000
# max        10.500000          1.000000       1.000000       1.000000
#
#              outlook  overall_rating  work_life_balance  culture_values  \
# count  805051.000000   805051.000000      660991.000000   621687.000000
# mean        0.255764        3.656927           3.374736        3.590585
# std         0.632094        1.177071           1.306846        1.325257
# min        -1.000000        1.000000           1.000000        1.000000
# 25%         0.000000        3.000000           2.000000        3.000000
# 50%         0.000000        4.000000           4.000000        4.000000
# 75%         1.000000        5.000000           4.000000        5.000000
# max         1.000000        5.000000           5.000000        5.000000
#
#        diversity_inclusion     career_opp  comp_benefits    senior_mgmt
# count        130891.000000  663325.000000  660809.000000  655247.000000
# mean              3.964245       3.458933       3.402215       3.178473
# std               1.193159       1.274151       1.220950       1.332946
# min               1.000000       1.000000       1.000000       1.000000
# 25%               3.000000       3.000000       3.000000       2.000000
# 50%               4.000000       4.000000       4.000000       3.000000
# 75%               5.000000       5.000000       4.000000       4.000000
# max               5.000000       5.000000       5.000000       5.000000

# %% [markdown]
# **BOX-PLOT**

# %%
columns = ['overall_rating', 'work_life_balance', 'culture_values', 'diversity_inclusion',
       'career_opp', 'comp_benefits', 'senior_mgmt']

fig,ax = plt.subplots(1,7,figsize=(12,5))

for column,curr_ax in zip(columns,ax.ravel()):
    curr_ax.boxplot(df_cleaned[column].dropna())
    curr_ax.set_title(f'{column}')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# On a scale of 1-5, this company's median overall rating is 4 which is pretty good. Breaking down to 6 categories, employees rated the highest in worklife-balance, diversity inclusion , carrer opportunities and company benefitis. Senior management rating's median value is 3, which is the lowest. Culture Values has a median rating as 4. There are a few outliers in career opportunities and culture values.

# %% [markdown]
# **LINEPLOT OF OVERALL RATINGS**

# %%
from datetime import datetime

fig,ax = plt.subplots(figsize = (10,5))

x = sorted(df_cleaned.index.year.unique())
y = df_cleaned.groupby(df_cleaned.index.year)['overall_rating'].mean()

ax.plot(x,y,color = 'blue' , marker = 'o' , label = 'overall_rating')
ax.set_title('overall_rating vs years')
ax.set_ylabel('overall_rating')
ax.set_xlabel('year')

plt.show()

# %% [markdown]
# There is a clear trend that the employee satisfaction has been increasing since 2010 with a some small dip in 2013 and 2014.we can also see a large decrease in employee satisfaction from 2008 to 2010 .

# %% [markdown]
# **Bar plot of overall recommendations**

# %%
count = df_cleaned['recommend'].value_counts(normalize = True)

fig,ax = plt.subplots(figsize = (5,5))

ax.bar(['recommend' , 'neutral' , 'not recommend'] , count, color = ['tab:green','tab:blue','tab:red'])
ax.set_title('Barplot of recommendations')
ax.set_ylabel('normalized frequency')

plt.show()

# %% [markdown]
# Overall, 50% of employees recommend this company, 20% do not recommend it, another 30% is neutral.

# %% [markdown]
# **Bar plots of sub-categories' ratings**

# %%
columns = ['overall_rating', 'work_life_balance', 'culture_values', 'diversity_inclusion',
       'career_opp', 'comp_benefits', 'senior_mgmt']

sub_count = df_cleaned[columns].mean()

fig,ax = plt.subplots(figsize = (12,5))
color1 = ['tab:blue' , 'tab:green','tab:orange','tab:red' , 'tab:olive','tab:pink','tab:purple']
ax.bar(columns , sub_count  , color = color1)
ax.set_title('Barplot of subcatagories ratings')
ax.set_ylabel('Average ratings')
ax.set_xticklabels(columns , rotation = 45)

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# **BARPLOT OF TOP 10 HIGHEST and LOWEST RATED LOCATION**

# %%
top10 = df_cleaned.groupby('location')['overall_rating'].mean().nlargest(10)
color2 = ['tab:blue' , 'tab:green','tab:orange','tab:red' , 'tab:olive','tab:pink',
          'tab:purple' , 'tab:brown','tab:gray','tab:cyan']

fig,ax = plt.subplots(figsize = (15,5))

ax.bar(top10.index , top10 , color = color2)
ax.set_title('BARPLOT OF TOP 10 HIGHEST RATED LOCATION')
ax.set_ylabel('ratings')
ax.set_xticklabels(top10.index , rotation = 45)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # Remove the CWD from sys.path while we load stuff.

# %%
low10 = df_cleaned.groupby('location')['overall_rating'].mean().nsmallest(10)
color2 = ['tab:blue' , 'tab:green','tab:orange','tab:red' , 'tab:olive','tab:pink',
          'tab:purple' , 'tab:brown','tab:gray','tab:cyan']

fig,ax = plt.subplots(figsize = (15,5))

ax.bar(low10.index , low10 , color = color2)
ax.set_title('BARPLOT OF TOP 10 LOWEST RATED LOCATION')
ax.set_ylabel('ratings')
ax.set_xticklabels(low10.index , rotation = 45)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# **Bar plots of overall ratings by employee type**

# %%
div_count = df_cleaned.groupby('Current Employee')['overall_rating'].mean()

fig,ax = plt.subplots(figsize = (4,5))

ax.bar(['cutrrent' , 'former']  ,div_count , color = ['tab:red' , 'tab:blue'])
ax.set_title('Bar plots of overall ratings by employee type')
ax.set_ylabel('ratings')

plt.show()

# %% [markdown]
# **Bar plots of most frequent reviewer job titles**

# %%
top20 = df_cleaned['job_title'].value_counts().nlargest(20)

plt.figure(figsize = (12,5))
sns.countplot(y = 'job_title' , data = df_cleaned , order = top20.index)
sns.set_context('talk')
plt.title('Bar plots of most frequent reviewer job titles')

plt.show()

# %% [markdown]
# Most employees choose not to disclose their job titles, for those who disclose their titles, they are manager and consultant.

# %% [markdown]
# **Bar plots of overall ratings of top jobs**

# %%
review = df_cleaned.loc[df_cleaned['job_title'].isin(top20.index) , ['job_title'  , 'overall_rating']]
review
# Out:
#                        job_title  overall_rating
# date_review
# 2008-02-05     Software Engineer               4
# 2008-02-11     Software Engineer               5
# 2008-02-14     Software Engineer               4
# 2008-02-14     Software Engineer               5
# 2008-02-14     Software Engineer               3
# ...                          ...             ...
# 2021-06-06               Cashier               3
# 2021-06-06               Cashier               3
# 2021-06-07        Senior Manager               5
# 2021-06-07               Manager               5
# 2021-06-07    Anonymous Employee               1
#
# [360754 rows x 2 columns]

# %%
ratings = df_cleaned.loc[]
# Out:
#   File "/tmp/ipykernel_27/1244697762.py", line 1
#     ratings = df_cleaned.loc[]
#                              ^
# SyntaxError: invalid syntax
